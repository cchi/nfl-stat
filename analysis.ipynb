# %%
import pandas as pd

# %% [markdown]
# # exploring nfl game outcomes

# %%
df = pd.read_csv( r'data/years_2014_games_games.csv' )

# %%
df
# Out:
#           Week  Day          Date Unnamed: 3            Winner/tie Unnamed: 5  \
# 0            1  Thu   September 4   boxscore      Seattle Seahawks        NaN
# 1            1  Sun   September 7   boxscore        Denver Broncos        NaN
# 2            1  Sun   September 7   boxscore     Carolina Panthers          @
# 3            1  Sun   September 7   boxscore   Pittsburgh Steelers        NaN
# 4            1  Sun   September 7   boxscore         New York Jets        NaN
# 5            1  Sun   September 7   boxscore    Cincinnati Bengals          @
# 6            1  Sun   September 7   boxscore        Miami Dolphins        NaN
# 7            1  Sun   September 7   boxscore        Houston Texans        NaN
# 8            1  Sun   September 7   boxscore       Atlanta Falcons        NaN
# 9            1  Sun   September 7   boxscore   San Francisco 49ers          @
# 10           1  Sun   September 7   boxscore   Philadelphia Eagles        NaN
# ...

# %% [markdown]
# # exploring interaction between offensive stats and time of possession

# %%
df = pd.read_csv( r'data/years_2014__drives.csv' )

# %%
df
# Out:
#    Unnamed: 0            Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0          Rk                    Tm          G        #Dr      Plays
# 1           1    Indianapolis Colts         16        205       1136
# 2           2   Philadelphia Eagles         16        203       1163
# 3           3       Oakland Raiders         16        198       1016
# 4           4        Denver Broncos         16        198       1096
# 5           5         Buffalo Bills         16        197       1058
# 6           6  Jacksonville Jaguars         16        195       1014
# 7           7        Houston Texans         16        194       1097
# 8           8      Cleveland Browns         16        193       1042
# 9           9       New York Giants         16        193       1112
# 10         10   Washington Redskins         16        192       1033
# 11         11      Tennessee Titans         16        191        941
# 12         12    Cincinnati Bengals         16        191       1051
# ...

# %%
df = pd.read_csv( r'data/years_2014__team_scoring.csv' )

# %%
df
# Out:
#     Rk                    Tm   G  RshTD  RecTD  PR TD  KR TD  FblTD  IntTD  \
# 0    1     Green Bay Packers  16   14.0   38.0    2.0    NaN    1.0    3.0
# 1    2        Denver Broncos  16   15.0   40.0    NaN    NaN    1.0    2.0
# 2    3   Philadelphia Eagles  16   16.0   27.0    2.0    2.0    2.0    2.0
# 3    4  New England Patriots  16   13.0   34.0    1.0    NaN    2.0    NaN
# 4    5        Dallas Cowboys  16   16.0   37.0    NaN    NaN    1.0    2.0
# 5    6    Indianapolis Colts  16    9.0   42.0    NaN    NaN    1.0    1.0
# 6    7   Pittsburgh Steelers  16   10.0   33.0    1.0    NaN    1.0    4.0
# 7    8      Baltimore Ravens  16   16.0   27.0    NaN    1.0    NaN    1.0
# 8    9    New Orleans Saints  16   16.0   33.0    NaN    NaN    NaN    NaN
# 9   10      Seattle Seahawks  16   20.0   20.0    NaN    NaN    NaN    2.0
# 10  11        Miami Dolphins  16   12.0   27.0    NaN    NaN    1.0    2.0
# ...

# %%
df = pd.read_csv( r'data/years_2014__team_stats.csv' )

# %%
df
# Out:
#    Unnamed: 0            Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0          Rk                    Tm          G         PF        Yds
# 1           1     Green Bay Packers         16        486       6178
# 2           2        Denver Broncos         16        482       6446
# 3           3   Philadelphia Eagles         16        474       6348
# 4           4  New England Patriots         16        468       5848
# 5           5        Dallas Cowboys         16        467       6138
# 6           6    Indianapolis Colts         16        458       6506
# 7           7   Pittsburgh Steelers         16        436       6577
# 8           8      Baltimore Ravens         16        409       5838
# 9           9    New Orleans Saints         16        401       6582
# 10         10      Seattle Seahawks         16        394       6012
# 11         11        Miami Dolphins         16        388       5601
# 12         12       Atlanta Falcons         16        381       6051
# ...

# %%
df = pd.read_csv( r'data/years_2014__team_scoring.csv' )

# %%
df
# Out:
#     Rk                    Tm   G  RshTD  RecTD  PR TD  KR TD  FblTD  IntTD  \
# 0    1     Green Bay Packers  16   14.0   38.0    2.0    NaN    1.0    3.0
# 1    2        Denver Broncos  16   15.0   40.0    NaN    NaN    1.0    2.0
# 2    3   Philadelphia Eagles  16   16.0   27.0    2.0    2.0    2.0    2.0
# 3    4  New England Patriots  16   13.0   34.0    1.0    NaN    2.0    NaN
# 4    5        Dallas Cowboys  16   16.0   37.0    NaN    NaN    1.0    2.0
# 5    6    Indianapolis Colts  16    9.0   42.0    NaN    NaN    1.0    1.0
# 6    7   Pittsburgh Steelers  16   10.0   33.0    1.0    NaN    1.0    4.0
# 7    8      Baltimore Ravens  16   16.0   27.0    NaN    1.0    NaN    1.0
# 8    9    New Orleans Saints  16   16.0   33.0    NaN    NaN    NaN    NaN
# 9   10      Seattle Seahawks  16   20.0   20.0    NaN    NaN    NaN    2.0
# 10  11        Miami Dolphins  16   12.0   27.0    NaN    NaN    1.0    2.0
# ...
